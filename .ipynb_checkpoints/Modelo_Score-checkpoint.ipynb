# %% [markdown]
# # Modelo Crediticio para clubes de futbol
# ##### Maximiliano Baylon Valdez
# ##### Sebastian Muñoz Baruqui
# ##### Sebastian Monsalve Gallegos

# %% [markdown]
# ### Importación de paqueterías

# %%
import pandas as pd
import numpy as np
from CDIN import CDIN as cd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Descarga de base de datos

# %%
data = pd.read_csv('Base Premier League.csv')
data
# Out:
#     POSICION          EQUIPO PRESUPUESTO PARA TRASNFERENCIAS  \
# 0          1       MAN CITY                   $96,000,000.00
# 1          2         ARSENAL                   $4,000,000.00
# 2          3           MAN U                  $15,000,000.00
# 3          4       NEWCASTLE                  $40,000,000.00
# 4          5       LIVERPOOL                   $5,000,000.00
# 5          6        BRIGHTON                   $7,000,000.00
# 6          7     ASTON VILLA                  $18,000,000.00
# 7          8       TOTTENHAM                  $19,000,000.00
# 8          9       BRENDFORD                   $7,000,000.00
# 9         10          FULHAM                   $1,000,000.00
# 10        11  CRYSTAL PALACE                   $3,000,000.00
# 11        12         CHELSEA                  $19,000,000.00
# 12        13          WOLVES                   $3,000,000.00
# 13        14        WEST HAM                  $14,000,000.00
# 14        15     BOURNEMOUTH                     $600,000.00
# 15        16          FOREST                   $9,000,000.00
# 16        17         EVERTON                  $31,000,000.00
# 17        18  LEICESTER CITY                  $22,000,000.00
# 18        19           LEEDS                   $3,000,000.00
# 19        20     SOUTHAMPTON                   $2,000,000.00
#
#    PRESUPUESTO PARA SUELDOS  INGRESOS POR TV BONO POR POSICION  \
# 0             $4,000,000.00  $135,600,000.00    $48,000,000.00
# 1             $3,000,000.00  $135,600,000.00    $45,600,000.00
# 2             $5,000,000.00  $135,600,000.00    $43,200,000.00
# 3             $2,000,000.00  $135,600,000.00    $40,800,000.00
# 4             $4,000,000.00  $135,600,000.00    $38,400,000.00
# 5             $1,000,000.00  $135,600,000.00    $36,000,000.00
# 6             $2,000,000.00  $135,600,000.00    $33,600,000.00
# 7             $3,000,000.00  $135,600,000.00    $31,200,000.00
# 8             $1,000,000.00  $135,600,000.00    $28,800,000.00
# 9             $1,000,000.00  $135,600,000.00    $26,400,000.00
# 10            $2,000,000.00  $135,600,000.00    $24,000,000.00
# 11            $6,000,000.00  $135,600,000.00    $21,600,000.00
# 12            $2,000,000.00  $135,600,000.00    $19,200,000.00
# 13            $2,000,000.00  $135,600,000.00    $16,800,000.00
# 14            $1,000,000.00  $135,600,000.00    $14,400,000.00
# 15            $2,000,000.00  $135,600,000.00    $12,000,000.00
# 16            $2,000,000.00  $135,600,000.00     $9,600,000.00
# 17            $2,000,000.00  $135,600,000.00     $7,200,000.00
# 18            $1,000,000.00  $135,600,000.00     $4,800,000.00
# 19            $2,000,000.00  $135,600,000.00     $2,400,000.00
#
#    BONOS CHAMPIONS LEAGUE BONOS EUROPA LEAGUE BONOS CONFERENCE  \
# 0          $85,300,000.00               $0.00            $0.00
# 1                   $0.00       $7,700,000.00            $0.00
# 2                   $0.00       $9,300,000.00            $0.00
# 3                   $0.00               $0.00            $0.00
# 4          $48,600,000.00               $0.00            $0.00
# 5                   $0.00               $0.00            $0.00
# 6                   $0.00               $0.00            $0.00
# 7          $45,400,000.00               $0.00            $0.00
# 8                   $0.00               $0.00            $0.00
# 9                   $0.00               $0.00            $0.00
# 10                  $0.00               $0.00            $0.00
# 11         $56,100,000.00               $0.00            $0.00
# 12                  $0.00               $0.00            $0.00
# 13                  $0.00               $0.00   $11,900,000.00
# 14                  $0.00               $0.00            $0.00
# 15                  $0.00               $0.00            $0.00
# 16                  $0.00               $0.00            $0.00
# 17                  $0.00               $0.00            $0.00
# 18                  $0.00               $0.00            $0.00
# 19                  $0.00               $0.00            $0.00
#
#    INGRESO POR ASCENSO INGRESOS POR TRASPASOS GASTOS POR TRASPASOS  \
# 0                $0.00        $162,170,000.00      $155,000,000.00
# 1                $0.00         $23,800,000.00      $191,900,000.00
# 2                $0.00         $23,650,000.00      $243,280,000.00
# 3                $0.00         $14,060,000.00      $185,350,000.00
# 4                $0.00         $80,700,000.00      $137,390,000.00
# 5                $0.00        $137,900,000.00       $55,700,000.00
# 6                $0.00         $54,000,000.00      $100,140,000.00
# 7                $0.00         $38,750,000.00      $177,900,000.00
# 8                $0.00          $3,600,000.00       $49,250,000.00
# 9      $170,000,000.00         $21,900,000.00       $72,200,000.00
# 10               $0.00          $5,460,000.00       $46,600,000.00
# 11               $0.00         $67,800,000.00      $611,490,000.00
# 12               $0.00         $62,870,000.00      $177,110,000.00
# 13               $0.00         $21,550,000.00      $186,500,000.00
# 14     $170,000,000.00                  $0.00       $83,100,000.00
# 15     $170,000,000.00          $5,000,000.00      $195,250,000.00
# 16               $0.00        $103,600,000.00       $78,200,000.00
# 17               $0.00         $81,400,000.00       $49,000,000.00
# 18               $0.00        $114,500,000.00      $151,390,000.00
# 19               $0.00          $5,500,000.00      $152,110,000.00
#
#    ASISTENCIA PROMEDIO PRECIO DE ENTRADA GANANCIAS ESTADIO   SCORE_MS  \
# 0               52,774            $44.00    $17,647,625.60  EXCELENTE
# 1               59,776            $28.50    $12,947,481.60  EXCELENTE
# 2               73,150            $36.00    $20,013,840.00  EXCELENTE
# 3               52,134            $44.00    $17,433,609.60  EXCELENTE
# 4               52,998             $9.00     $3,625,063.20  EXCELENTE
# 5               30,943            $30.00     $7,055,004.00  EXCELENTE
# 6               41,681            $40.50    $12,829,411.80      BUENO
# 7               56,523            $37.00    $15,894,267.60  EXCELENTE
# 8               16,912            $30.00     $3,855,936.00      BUENO
# 9               19,896            $35.00     $5,292,336.00      BUENO
# 10              24,282            $42.00     $7,750,814.40      BUENO
# 11              37,812            $25.00     $7,184,280.00      BUENO
# 12              30,765            $35.00     $8,183,490.00       MALO
# 13              62,447            $30.00    $14,237,916.00      BUENO
# 14              11,189            $28.00     $2,381,019.20      BUENO
# 15              28,000            $38.00     $8,086,400.00       MALO
# 16              38,968            $55.00    $16,288,624.00      BUENO
# 17              31,941            $30.00     $7,282,548.00       MALO
# 18              36,308            $25.00     $6,898,520.00       MALO
# 19              29,939            $20.00     $4,550,728.00       MALO
#
#     Unnamed: 16       Unnamed: 17
# 0           NaN   $393,717,625.60
# 1           NaN    $40,747,481.60
# 2           NaN     $8,483,840.00
# 3           NaN    $64,543,609.60
# 4           NaN   $178,535,063.20
# 5           NaN   $268,855,004.00
# 6           NaN   $155,889,411.80
# 7           NaN   $110,944,267.60
# 8           NaN   $130,605,936.00
# 9           NaN   $288,992,336.00
# 10          NaN   $131,210,814.40
# 11          NaN  -$298,205,720.00
# 12          NaN    $53,743,490.00
# 13          NaN    $29,587,916.00
# 14          NaN   $240,881,019.20
# 15          NaN   $146,436,400.00
# 16          NaN   $219,888,624.00
# 17          NaN   $206,482,548.00
# 18          NaN   $114,408,520.00
# 19          NaN       -$59,272.00

# %% [markdown]
# ### Limpieza de Datos

# %%
cd.dqr(data)
# Out:
#                                                          Nombres Tipo_Dato  \
# POSICION                                                POSICION     int64
# EQUIPO                                                    EQUIPO    object
# PRESUPUESTO PARA TRASNFERENCIAS  PRESUPUESTO PARA TRASNFERENCIAS    object
# PRESUPUESTO PARA SUELDOS                PRESUPUESTO PARA SUELDOS    object
# INGRESOS POR TV                                  INGRESOS POR TV    object
# BONO POR POSICION                              BONO POR POSICION    object
# BONOS CHAMPIONS LEAGUE                    BONOS CHAMPIONS LEAGUE    object
# BONOS EUROPA LEAGUE                          BONOS EUROPA LEAGUE    object
# BONOS CONFERENCE                                BONOS CONFERENCE    object
# INGRESO POR ASCENSO                          INGRESO POR ASCENSO    object
# INGRESOS POR TRASPASOS                    INGRESOS POR TRASPASOS    object
# GASTOS POR TRASPASOS                        GASTOS POR TRASPASOS    object
# ASISTENCIA PROMEDIO                          ASISTENCIA PROMEDIO    object
# PRECIO DE ENTRADA                              PRECIO DE ENTRADA    object
# GANANCIAS ESTADIO                              GANANCIAS ESTADIO    object
# SCORE_MS                                                SCORE_MS    object
# Unnamed: 16                                          Unnamed: 16   float64
# Unnamed: 17                                          Unnamed: 17    object
#
#                                  Datos_Faltantes  Valores_Presentes  \
# POSICION                                       0                 20
# EQUIPO                                         0                 20
# PRESUPUESTO PARA TRASNFERENCIAS                0                 20
# PRESUPUESTO PARA SUELDOS                       0                 20
# INGRESOS POR TV                                0                 20
# BONO POR POSICION                              0                 20
# BONOS CHAMPIONS LEAGUE                         0                 20
# BONOS EUROPA LEAGUE                            0                 20
# BONOS CONFERENCE                               0                 20
# INGRESO POR ASCENSO                            0                 20
# INGRESOS POR TRASPASOS                         0                 20
# GASTOS POR TRASPASOS                           0                 20
# ASISTENCIA PROMEDIO                            0                 20
# PRECIO DE ENTRADA                              0                 20
# GANANCIAS ESTADIO                              0                 20
# SCORE_MS                                       0                 20
# Unnamed: 16                                   20                  0
# Unnamed: 17                                    0                 20
#
#                                  Num_Valores_Unicos              Min  \
# POSICION                                         20                1
# EQUIPO                                           20          ARSENAL
# PRESUPUESTO PARA TRASNFERENCIAS                  16    $1,000,000.00
# PRESUPUESTO PARA SUELDOS                          6    $1,000,000.00
# INGRESOS POR TV                                   1  $135,600,000.00
# BONO POR POSICION                                20   $12,000,000.00
# BONOS CHAMPIONS LEAGUE                            5            $0.00
# BONOS EUROPA LEAGUE                               3            $0.00
# BONOS CONFERENCE                                  2            $0.00
# INGRESO POR ASCENSO                               2            $0.00
# INGRESOS POR TRASPASOS                           20            $0.00
# GASTOS POR TRASPASOS                             20  $100,140,000.00
# ASISTENCIA PROMEDIO                              20           11,189
# PRECIO DE ENTRADA                                14           $20.00
# GANANCIAS ESTADIO                                20   $12,829,411.80
# SCORE_MS                                          3            BUENO
# Unnamed: 16                                       0              NaN
# Unnamed: 17                                      20  $110,944,267.60
#
#                                              Max  Categorica
# POSICION                                      20       False
# EQUIPO                                    WOLVES        True
# PRESUPUESTO PARA TRASNFERENCIAS   $96,000,000.00        True
# PRESUPUESTO PARA SUELDOS           $6,000,000.00        True
# INGRESOS POR TV                  $135,600,000.00        True
# BONO POR POSICION                  $9,600,000.00        True
# BONOS CHAMPIONS LEAGUE            $85,300,000.00        True
# BONOS EUROPA LEAGUE                $9,300,000.00        True
# BONOS CONFERENCE                  $11,900,000.00        True
# INGRESO POR ASCENSO              $170,000,000.00        True
# INGRESOS POR TRASPASOS            $81,400,000.00        True
# GASTOS POR TRASPASOS              $83,100,000.00        True
# ASISTENCIA PROMEDIO                       73,150        True
# PRECIO DE ENTRADA                          $9.00        True
# GANANCIAS ESTADIO                  $8,183,490.00        True
# SCORE_MS                                    MALO        True
# Unnamed: 16                                  NaN       False
# Unnamed: 17                          -$59,272.00        True

# %%
data["PRESUPUESTO PARA TRASNFERENCIAS"] = data["PRESUPUESTO PARA TRASNFERENCIAS"].apply(cd.remove_punctuation).astype(float)
data["PRESUPUESTO PARA SUELDOS"] = data["PRESUPUESTO PARA SUELDOS"].apply(cd.remove_punctuation).astype(float)
data["INGRESOS POR TV"] = data["INGRESOS POR TV"].apply(cd.remove_punctuation).astype(float)
data["BONO POR POSICION"] = data["BONO POR POSICION"].apply(cd.remove_punctuation).astype(float)
data["BONOS CHAMPIONS LEAGUE"] = data["BONOS CHAMPIONS LEAGUE"].apply(cd.remove_punctuation).astype(float)
data["BONOS EUROPA LEAGUE"] = data["BONOS EUROPA LEAGUE"].apply(cd.remove_punctuation).astype(float)
data["BONOS CONFERENCE"] = data["BONOS CONFERENCE"].apply(cd.remove_punctuation).astype(float)
data["INGRESO POR ASCENSO"] = data["INGRESO POR ASCENSO"].apply(cd.remove_punctuation).astype(float)
data["INGRESOS POR TRASPASOS"] = data["INGRESOS POR TRASPASOS"].apply(cd.remove_punctuation).astype(float)
data["GASTOS POR TRASPASOS"] = -1*(data["GASTOS POR TRASPASOS"].apply(cd.remove_punctuation).astype(float))
data["ASISTENCIA PROMEDIO"] = data["ASISTENCIA PROMEDIO"].apply(cd.remove_punctuation).astype(float)
data["PRECIO DE ENTRADA"] = data["PRECIO DE ENTRADA"].apply(cd.remove_punctuation).astype(float)
data["GANANCIAS ESTADIO"] = data["GANANCIAS ESTADIO"].apply(cd.remove_punctuation).astype(float)
data = data.drop(["Unnamed: 16","Unnamed: 17"], axis=1)
data
# Out:
#     POSICION          EQUIPO  PRESUPUESTO PARA TRASNFERENCIAS  \
# 0          1       MAN CITY                      9.600000e+09
# 1          2         ARSENAL                     4.000000e+08
# 2          3           MAN U                     1.500000e+09
# 3          4       NEWCASTLE                     4.000000e+09
# 4          5       LIVERPOOL                     5.000000e+08
# 5          6        BRIGHTON                     7.000000e+08
# 6          7     ASTON VILLA                     1.800000e+09
# 7          8       TOTTENHAM                     1.900000e+09
# 8          9       BRENDFORD                     7.000000e+08
# 9         10          FULHAM                     1.000000e+08
# 10        11  CRYSTAL PALACE                     3.000000e+08
# 11        12         CHELSEA                     1.900000e+09
# 12        13          WOLVES                     3.000000e+08
# 13        14        WEST HAM                     1.400000e+09
# 14        15     BOURNEMOUTH                     6.000000e+07
# 15        16          FOREST                     9.000000e+08
# 16        17         EVERTON                     3.100000e+09
# 17        18  LEICESTER CITY                     2.200000e+09
# 18        19           LEEDS                     3.000000e+08
# 19        20     SOUTHAMPTON                     2.000000e+08
#
#     PRESUPUESTO PARA SUELDOS  INGRESOS POR TV  BONO POR POSICION  \
# 0                400000000.0     1.356000e+10       4.800000e+09
# 1                300000000.0     1.356000e+10       4.560000e+09
# 2                500000000.0     1.356000e+10       4.320000e+09
# 3                200000000.0     1.356000e+10       4.080000e+09
# 4                400000000.0     1.356000e+10       3.840000e+09
# 5                100000000.0     1.356000e+10       3.600000e+09
# 6                200000000.0     1.356000e+10       3.360000e+09
# 7                300000000.0     1.356000e+10       3.120000e+09
# 8                100000000.0     1.356000e+10       2.880000e+09
# 9                100000000.0     1.356000e+10       2.640000e+09
# 10               200000000.0     1.356000e+10       2.400000e+09
# 11               600000000.0     1.356000e+10       2.160000e+09
# 12               200000000.0     1.356000e+10       1.920000e+09
# 13               200000000.0     1.356000e+10       1.680000e+09
# 14               100000000.0     1.356000e+10       1.440000e+09
# 15               200000000.0     1.356000e+10       1.200000e+09
# 16               200000000.0     1.356000e+10       9.600000e+08
# 17               200000000.0     1.356000e+10       7.200000e+08
# 18               100000000.0     1.356000e+10       4.800000e+08
# 19               200000000.0     1.356000e+10       2.400000e+08
#
#     BONOS CHAMPIONS LEAGUE  BONOS EUROPA LEAGUE  BONOS CONFERENCE  \
# 0             8.530000e+09                  0.0      0.000000e+00
# 1             0.000000e+00          770000000.0      0.000000e+00
# 2             0.000000e+00          930000000.0      0.000000e+00
# 3             0.000000e+00                  0.0      0.000000e+00
# 4             4.860000e+09                  0.0      0.000000e+00
# 5             0.000000e+00                  0.0      0.000000e+00
# 6             0.000000e+00                  0.0      0.000000e+00
# 7             4.540000e+09                  0.0      0.000000e+00
# 8             0.000000e+00                  0.0      0.000000e+00
# 9             0.000000e+00                  0.0      0.000000e+00
# 10            0.000000e+00                  0.0      0.000000e+00
# 11            5.610000e+09                  0.0      0.000000e+00
# 12            0.000000e+00                  0.0      0.000000e+00
# 13            0.000000e+00                  0.0      1.190000e+09
# 14            0.000000e+00                  0.0      0.000000e+00
# 15            0.000000e+00                  0.0      0.000000e+00
# 16            0.000000e+00                  0.0      0.000000e+00
# 17            0.000000e+00                  0.0      0.000000e+00
# 18            0.000000e+00                  0.0      0.000000e+00
# 19            0.000000e+00                  0.0      0.000000e+00
#
#     INGRESO POR ASCENSO  INGRESOS POR TRASPASOS  GASTOS POR TRASPASOS  \
# 0          0.000000e+00            1.621700e+10         -1.550000e+10
# 1          0.000000e+00            2.380000e+09         -1.919000e+10
# 2          0.000000e+00            2.365000e+09         -2.432800e+10
# 3          0.000000e+00            1.406000e+09         -1.853500e+10
# 4          0.000000e+00            8.070000e+09         -1.373900e+10
# 5          0.000000e+00            1.379000e+10         -5.570000e+09
# 6          0.000000e+00            5.400000e+09         -1.001400e+10
# 7          0.000000e+00            3.875000e+09         -1.779000e+10
# 8          0.000000e+00            3.600000e+08         -4.925000e+09
# 9          1.700000e+10            2.190000e+09         -7.220000e+09
# 10         0.000000e+00            5.460000e+08         -4.660000e+09
# 11         0.000000e+00            6.780000e+09         -6.114900e+10
# 12         0.000000e+00            6.287000e+09         -1.771100e+10
# 13         0.000000e+00            2.155000e+09         -1.865000e+10
# 14         1.700000e+10            0.000000e+00         -8.310000e+09
# 15         1.700000e+10            5.000000e+08         -1.952500e+10
# 16         0.000000e+00            1.036000e+10         -7.820000e+09
# 17         0.000000e+00            8.140000e+09         -4.900000e+09
# 18         0.000000e+00            1.145000e+10         -1.513900e+10
# 19         0.000000e+00            5.500000e+08         -1.521100e+10
#
#     ASISTENCIA PROMEDIO  PRECIO DE ENTRADA  GANANCIAS ESTADIO   SCORE_MS  \
# 0               52774.0             4400.0       1.764763e+09  EXCELENTE
# 1               59776.0             2850.0       1.294748e+09  EXCELENTE
# 2               73150.0             3600.0       2.001384e+09  EXCELENTE
# 3               52134.0             4400.0       1.743361e+09  EXCELENTE
# 4               52998.0              900.0       3.625063e+08  EXCELENTE
# 5               30943.0             3000.0       7.055004e+08  EXCELENTE
# 6               41681.0             4050.0       1.282941e+09      BUENO
# 7               56523.0             3700.0       1.589427e+09  EXCELENTE
# 8               16912.0             3000.0       3.855936e+08      BUENO
# 9               19896.0             3500.0       5.292336e+08      BUENO
# 10              24282.0             4200.0       7.750814e+08      BUENO
# 11              37812.0             2500.0       7.184280e+08      BUENO
# 12              30765.0             3500.0       8.183490e+08       MALO
# 13              62447.0             3000.0       1.423792e+09      BUENO
# 14              11189.0             2800.0       2.381019e+08      BUENO
# 15              28000.0             3800.0       8.086400e+08       MALO
# 16              38968.0             5500.0       1.628862e+09      BUENO
# 17              31941.0             3000.0       7.282548e+08       MALO
# 18              36308.0             2500.0       6.898520e+08       MALO
# 19              29939.0             2000.0       4.550728e+08       MALO
#
#     Unnamed: 16       Unnamed: 17
# 0           NaN   $393,717,625.60
# 1           NaN    $40,747,481.60
# 2           NaN     $8,483,840.00
# 3           NaN    $64,543,609.60
# 4           NaN   $178,535,063.20
# 5           NaN   $268,855,004.00
# 6           NaN   $155,889,411.80
# 7           NaN   $110,944,267.60
# 8           NaN   $130,605,936.00
# 9           NaN   $288,992,336.00
# 10          NaN   $131,210,814.40
# 11          NaN  -$298,205,720.00
# 12          NaN    $53,743,490.00
# 13          NaN    $29,587,916.00
# 14          NaN   $240,881,019.20
# 15          NaN   $146,436,400.00
# 16          NaN   $219,888,624.00
# 17          NaN   $206,482,548.00
# 18          NaN   $114,408,520.00
# 19          NaN       -$59,272.00

# %%
cd.dqr(data)
# Out:
#                                                          Nombres Tipo_Dato  \
# POSICION                                                POSICION     int64
# EQUIPO                                                    EQUIPO    object
# PRESUPUESTO PARA TRASNFERENCIAS  PRESUPUESTO PARA TRASNFERENCIAS   float64
# PRESUPUESTO PARA SUELDOS                PRESUPUESTO PARA SUELDOS   float64
# INGRESOS POR TV                                  INGRESOS POR TV   float64
# BONO POR POSICION                              BONO POR POSICION   float64
# BONOS CHAMPIONS LEAGUE                    BONOS CHAMPIONS LEAGUE   float64
# BONOS EUROPA LEAGUE                          BONOS EUROPA LEAGUE   float64
# BONOS CONFERENCE                                BONOS CONFERENCE   float64
# INGRESO POR ASCENSO                          INGRESO POR ASCENSO   float64
# INGRESOS POR TRASPASOS                    INGRESOS POR TRASPASOS   float64
# GASTOS POR TRASPASOS                        GASTOS POR TRASPASOS   float64
# ASISTENCIA PROMEDIO                          ASISTENCIA PROMEDIO   float64
# PRECIO DE ENTRADA                              PRECIO DE ENTRADA   float64
# GANANCIAS ESTADIO                              GANANCIAS ESTADIO   float64
# SCORE_MS                                                SCORE_MS    object
# Unnamed: 16                                          Unnamed: 16   float64
# Unnamed: 17                                          Unnamed: 17    object
#
#                                  Datos_Faltantes  Valores_Presentes  \
# POSICION                                       0                 20
# EQUIPO                                         0                 20
# PRESUPUESTO PARA TRASNFERENCIAS                0                 20
# PRESUPUESTO PARA SUELDOS                       0                 20
# INGRESOS POR TV                                0                 20
# BONO POR POSICION                              0                 20
# BONOS CHAMPIONS LEAGUE                         0                 20
# BONOS EUROPA LEAGUE                            0                 20
# BONOS CONFERENCE                               0                 20
# INGRESO POR ASCENSO                            0                 20
# INGRESOS POR TRASPASOS                         0                 20
# GASTOS POR TRASPASOS                           0                 20
# ASISTENCIA PROMEDIO                            0                 20
# PRECIO DE ENTRADA                              0                 20
# GANANCIAS ESTADIO                              0                 20
# SCORE_MS                                       0                 20
# Unnamed: 16                                   20                  0
# Unnamed: 17                                    0                 20
#
#                                  Num_Valores_Unicos              Min  \
# POSICION                                         20                1
# EQUIPO                                           20          ARSENAL
# PRESUPUESTO PARA TRASNFERENCIAS                  16       60000000.0
# PRESUPUESTO PARA SUELDOS                          6      100000000.0
# INGRESOS POR TV                                   1    13560000000.0
# BONO POR POSICION                                20      240000000.0
# BONOS CHAMPIONS LEAGUE                            5              0.0
# BONOS EUROPA LEAGUE                               3              0.0
# BONOS CONFERENCE                                  2              0.0
# INGRESO POR ASCENSO                               2              0.0
# INGRESOS POR TRASPASOS                           20              0.0
# GASTOS POR TRASPASOS                             20   -61149000000.0
# ASISTENCIA PROMEDIO                              20          11189.0
# PRECIO DE ENTRADA                                14            900.0
# GANANCIAS ESTADIO                                20      238101920.0
# SCORE_MS                                          3            BUENO
# Unnamed: 16                                       0              NaN
# Unnamed: 17                                      20  $110,944,267.60
#
#                                            Max  Categorica
# POSICION                                    20       False
# EQUIPO                                  WOLVES        True
# PRESUPUESTO PARA TRASNFERENCIAS   9600000000.0       False
# PRESUPUESTO PARA SUELDOS           600000000.0       False
# INGRESOS POR TV                  13560000000.0       False
# BONO POR POSICION                 4800000000.0       False
# BONOS CHAMPIONS LEAGUE            8530000000.0       False
# BONOS EUROPA LEAGUE                930000000.0       False
# BONOS CONFERENCE                  1190000000.0       False
# INGRESO POR ASCENSO              17000000000.0       False
# INGRESOS POR TRASPASOS           16217000000.0       False
# GASTOS POR TRASPASOS             -4660000000.0       False
# ASISTENCIA PROMEDIO                    73150.0       False
# PRECIO DE ENTRADA                       5500.0       False
# GANANCIAS ESTADIO                 2001384000.0       False
# SCORE_MS                                  MALO        True
# Unnamed: 16                                NaN       False
# Unnamed: 17                        -$59,272.00        True

# %% [markdown]
# ### Analisis Exploratorio de los Datos

# %% [markdown]
# #### Matriz de Correlación

# %%
# Convertir la columna SCORE_MS a una variable categórica ordinal
score_mapping = {'EXCELENTE': 3, 'BUENO': 2, 'MALO': 1}
data['SCORE_NUMERIC'] = data['SCORE_MS'].map(score_mapping)

# Calcular correlaciones con la calificación numérica
correlation_matrix = data.corr()

# Visualizar la matriz de correlación
plt.figure(figsize=(12, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title("Matriz de Correlación")
plt.show()

# Mostrar correlaciones específicas con SCORE_NUMERIC
correlation_with_score = correlation_matrix['SCORE_NUMERIC'].sort_values(ascending=False)
correlation_with_score
# Out:
# SCORE_NUMERIC                      1.000000
# BONO POR POSICION                  0.880527
# ASISTENCIA PROMEDIO                0.572327
# GANANCIAS ESTADIO                  0.489395
# BONOS CHAMPIONS LEAGUE             0.412627
# PRESUPUESTO PARA SUELDOS           0.393504
# BONOS EUROPA LEAGUE                0.388659
# PRESUPUESTO PARA TRASNFERENCIAS    0.355195
# INGRESOS POR TRASPASOS             0.149884
# PRECIO DE ENTRADA                  0.096130
# BONOS CONFERENCE                  -0.029867
# GASTOS POR TRASPASOS              -0.060698
# INGRESO POR ASCENSO               -0.236991
# POSICION                          -0.880527
# INGRESOS POR TV                         NaN
# Unnamed: 16                             NaN
# Name: SCORE_NUMERIC, dtype: float64

# %% [markdown]
# #### Asignar pesos a las variables

# %%
# Asignar los pesos a cada variable
weights = {
    'BONO POR POSICION': 0.20,
    'BONOS CHAMPIONS LEAGUE': 0.15,
    'PRESUPUESTO PARA SUELDOS': 0.10,
    'GASTOS POR TRASPASOS': 0.11,
    'PRESUPUESTO PARA TRASNFERENCIAS': 0.01,
    'BONOS EUROPA LEAGUE': 0.10,
    'INGRESOS POR TRASPASOS': 0.07,
    'BONOS CONFERENCE': 0.10,
    'INGRESO POR ASCENSO': 0.05,
    'GANANCIAS ESTADIO': 0.10,
    'INGRESOS POR TV': 0.01
    
}

# Normalizar las variables para que tengan el mismo rango antes de aplicar los pesos
normalized_data = data[weights.keys()].apply(lambda x: (x - x.min()) / (x.max() - x.min()))

# Calcular el índice de crédito ponderado
data['CREDIT_INDEX'] = normalized_data.mul(weights).sum(axis=1)

# Verificar el índice calculado
data[['EQUIPO', 'SCORE_MS', 'CREDIT_INDEX']]
# Out:
#             EQUIPO   SCORE_MS  CREDIT_INDEX
# 0        MAN CITY   EXCELENTE      0.665472
# 1          ARSENAL  EXCELENTE      0.464530
# 2            MAN U  EXCELENTE      0.542366
# 3        NEWCASTLE  EXCELENTE      0.366968
# 4        LIVERPOOL  EXCELENTE      0.438029
# 5         BRIGHTON  EXCELENTE      0.342299
# 6      ASTON VILLA      BUENO      0.340804
# 7        TOTTENHAM  EXCELENTE      0.425876
# 8        BRENDFORD      BUENO      0.235863
# 9           FULHAM      BUENO      0.286284
# 10  CRYSTAL PALACE      BUENO      0.257799
# 11         CHELSEA      BUENO      0.341297
# 12          WOLVES       MALO      0.238567
# 13        WEST HAM      BUENO      0.343865
# 14     BOURNEMOUTH      BUENO      0.205524
# 15          FOREST       MALO      0.228554
# 16         EVERTON      BUENO      0.282204
# 17  LEICESTER CITY       MALO      0.215762
# 18           LEEDS       MALO      0.175416
# 19     SOUTHAMPTON       MALO      0.124280

# %% [markdown]
# #### Distribución de los datos

# %%
# Explorar la distribución del índice de crédito
plt.figure(figsize=(10, 6))
sns.histplot(data['CREDIT_INDEX'], kde=True, bins=20)
plt.title("Distribución del Índice de Crédito")
plt.xlabel("Índice de Crédito")
plt.ylabel("Frecuencia")
plt.show()

# Calcular percentiles para sugerir umbrales
percentiles = data['CREDIT_INDEX'].quantile([0.33, 0.66]).values
percentiles
# Out:
# array([0.24375924, 0.3431446 ])

# %% [markdown]
# ### Modelo básico de Crédito

# %%
# Aplicar los umbrales para clasificar a cada equipo
def classify_credit_score(index):
    if index <= .25:
        return 'MALO'
    elif index <= .39:
        return 'BUENO'
    else:
        return 'EXCELENTE'

data['MODELED_SCORE'] = data['CREDIT_INDEX'].apply(classify_credit_score)

# Comparar las nuevas calificaciones con las originales
comparison = data[['EQUIPO', 'SCORE_MS', 'MODELED_SCORE', 'CREDIT_INDEX']]
comparison
# Out:
#             EQUIPO   SCORE_MS MODELED_SCORE  CREDIT_INDEX
# 0        MAN CITY   EXCELENTE     EXCELENTE      0.665472
# 1          ARSENAL  EXCELENTE     EXCELENTE      0.464530
# 2            MAN U  EXCELENTE     EXCELENTE      0.542366
# 3        NEWCASTLE  EXCELENTE         BUENO      0.366968
# 4        LIVERPOOL  EXCELENTE     EXCELENTE      0.438029
# 5         BRIGHTON  EXCELENTE         BUENO      0.342299
# 6      ASTON VILLA      BUENO         BUENO      0.340804
# 7        TOTTENHAM  EXCELENTE     EXCELENTE      0.425876
# 8        BRENDFORD      BUENO          MALO      0.235863
# 9           FULHAM      BUENO         BUENO      0.286284
# 10  CRYSTAL PALACE      BUENO         BUENO      0.257799
# 11         CHELSEA      BUENO         BUENO      0.341297
# 12          WOLVES       MALO          MALO      0.238567
# 13        WEST HAM      BUENO         BUENO      0.343865
# 14     BOURNEMOUTH      BUENO          MALO      0.205524
# 15          FOREST       MALO          MALO      0.228554
# 16         EVERTON      BUENO         BUENO      0.282204
# 17  LEICESTER CITY       MALO          MALO      0.215762
# 18           LEEDS       MALO          MALO      0.175416
# 19     SOUTHAMPTON       MALO          MALO      0.124280

# %% [markdown]
# #### Coincidencia de los resultados

# %%
coincidencias = (data['SCORE_MS'] == data['MODELED_SCORE']).sum()
porcentaje_coincidencia = (coincidencias / len(data))*100

print(f"El porcentaje de coincidencia entre las dos columnas es: {porcentaje_coincidencia:.2f}%")
# Out:
# El porcentaje de coincidencia entre las dos columnas es: 80.00%
